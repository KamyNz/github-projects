# %%
# General purpose libraries
import os, sys
import collections
import time
from datetime import datetime, timedelta
import parsedatetime as pdt

# %%
# Other that I should be using
import logging
from colorama import init, Fore, Back, Style
import begin

# %%
#Using begin
import begin
@begin.subcommand
def main_dir_path(answer_from_terminal):
    "What is the path of main irectory where is data folder?"
    logging.info(answer_from_terminal)
@begin.subcommand
def lower_dir_path(answer_from_terminal):
    "What is the path of the lower directory where is data folder?"
    logging.info(answer_from_terminal)

# %% [markdown]
# ### Parsing crontab output

# %%
# Change directory of output
#os.chdir("/home/asisbio2/Documents/tareas/projects/semester1-2018/6_studying/01_curso_linux_efox/") # ubuntu Desktop
os.chdir("/home/asisbio2/Documents/CENICANA/work/04_automating_server_stuff/01_curso_linux_efox/") # Ubuntu-portatil

# %%
def getting_temp_date(line):
    temp_date ="Error"
    #print(infile[idx-1])
    #print(infile[idx-1].split())
    list_date = [infile[idx].split()[0],
                infile[idx].split()[1],
                infile[idx].split()[2],
                infile[idx].split()[5],
                infile[idx].split()[3]]

    date_concatenated = " ".join(list_date)
    #print date_concatenated
    #dt, result = cal.parseDT(date_concatenated)
    #temp_date = dt.ctime()
    temp_date = date_concatenated
    
    return(temp_date)


def getting_tem_tuple(line):
    temp_name_disk_final = ""
    temp_usage=""
    temp_tuple = ("Error","Error")
    
    # Gettign list of tuples
    temp_split1 = line.split("%")
    #print(temp_split1)
    temp_name_disk = temp_split1[1].strip()

    #print(temp_split1, temp_name_disk.strip())
    if(temp_name_disk.startswith("/bio")): # Condition to get name_disk of /bio
        temp_name_disk_final = temp_name_disk
        
        # Step to get temp_usage
        len_temp = len(temp_split1[0].split("  "))
        #print(temp_split1[0].split("  "),len_temp)
        temp_usage = temp_split1[0].split("  ")[len_temp-1]
        temp_usage = temp_usage.replace(" ","")

        if(temp_usage.isdigit()):
            temp_usage = int(temp_usage)
        else:
            import re
            temp_usage_mod1 = re.split('M|K|G|T',temp_usage)
            temp_usage = temp_usage_mod1[1]
            logging.warning("Luego de split, el numero de available usage no se puede pasar a int")
            
    #temp_tuple = (temp_name_disk,tem_usage)
    
    return(temp_name_disk_final,temp_usage)

# this functions is not mine
def rename1(self,key,new_key):
    ind = self._keys.index(key)  #get the index of old key, O(N) operation
    self._keys[ind] = new_key    #replace old key with new key in self._keys
    self[new_key] = self[key]    #add the new key, this is added at the end of self._keys
    self._keys.pop(-1)           #pop the last item in self._keys

def rename2(old_dict,old_name,new_name):
    new_dict = {}
    for key,value in zip(old_dict.keys(),old_dict.values()):
        new_key = key if key != old_name else new_name
        new_dict[new_key] = old_dict[key]
    return new_dict

# %% [markdown]
# ### Running loop where the disk name and temp_usage is obtained

# %%
# Using collections to fill the dict
from collections import defaultdict

# Using with to not have to use f.open and f.close
infile = open("output/df_h_output_biomega.txt","r").readlines()

list_aux_dates = list()
list_sub_tuples = list()
temp_tuple=("","")
dict_temp = collections.OrderedDict()
for idx,line in enumerate(infile):
   
    #print(line)
    #print(previous,line)
    if(line.startswith("lun")!=True and line.startswith("Filesystem") != True):
        temp_name_disk,temp_usage = getting_tem_tuple(line) 
        #continue
        temp_tuple = (temp_name_disk,temp_usage)
        if(not all(temp_tuple) != True):
            list_sub_tuples.append(temp_tuple)
    if(line.startswith("lun") ):
        temp_date = getting_temp_date(line)
        list_aux_dates.append(temp_date)
    
    #if(len(list_sub_tuples)==9):
    #print(temp_date,list_sub_tuples)
    
    if(line.startswith("Filesystem") == True and len(list_sub_tuples)>=9 and len(list_sub_tuples)%9==0):
            print(idx,temp_date,len(list_sub_tuples),list_sub_tuples[(len(list_sub_tuples)-9):len(list_sub_tuples)])
            dict_temp[idx] = list_sub_tuples[(len(list_sub_tuples)-9):len(list_sub_tuples)]
    
    #if(line.startswith("Filesystem") == True and len(list_sub_tuples)==0):
    #    #print(temp_date,list_sub_tuples)
    #    temp_date1 = temp_date
    #if(line.startswith("Filesystem") == True and len(list_sub_tuples)==9):    
    #        dict_temp[temp_date1]=list_sub_tuples
    #        print(temp_date1,list_sub_tuples)
    #else:
    #    if(line.startswith("Filesystem") == True and len(list_sub_tuples)>9 and len(list_sub_tuples)%9==0):
    #        print(temp_date,len(list_sub_tuples),list_sub_tuples[(len(list_sub_tuples)-9):len(list_sub_tuples)])
# Out:
# WARNING:root:Luego de split, el numero de available usage no se puede pasar a int
# (21, 'lun oct 15 2018 08:15:01', 9, [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71)])
# (41, 'lun oct 22 2018 08:15:01', 18, [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71)])
# (61, 'lun oct 29 2018 08:15:01', 27, [('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71)])
# (81, 'lun nov 5 2018 08:15:01', 36, [('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71)])
# (101, 'lun nov 12 2018 08:15:01', 45, [('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71)])
# (121, 'lun nov 19 2018 08:15:01', 54, [('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95)])
# (141, 'lun nov 26 2018 08:15:01', 63, [('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95)])
# (161, 'lun dic 3 2018 08:15:01', 72, [('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92)])
# (181, 'lun dic 10 2018 08:15:01', 81, [('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92)])
# (201, 'lun dic 17 2018 08:15:01', 90, [('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93)])
# (221, 'lun dic 24 2018 08:15:01', 99, [('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98)])
# (241, 'lun dic 31 2018 08:15:01', 108, [('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1)])
# (261, 'lun ene 7 2019 08:15:01', 117, [('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1)])
# (281, 'lun ene 14 2019 08:15:01', 126, [('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1)])
# (300, 'lun ene 21 2019 08:15:01', 135, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92)])
# (320, 'lun ene 28 2019 08:15:01', 144, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# (340, 'lun feb 4 2019 08:15:01', 153, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# (360, 'lun feb 11 2019 08:15:01', 162, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# (380, 'lun feb 18 2019 08:15:01', 171, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# (400, 'lun feb 25 2019 08:15:01', 180, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# (420, 'lun mar 4 2019 08:15:02', 189, [('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# (440, 'lun mar 11 2019 08:15:01', 198, [('/biosamba', 45), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])

# %%
infile
# Out:
# ['lun oct  8 12:52:00 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  212M  303G   1% /run\n',
#  '/dev/sda3                    265G  120G  132G  48% /\n',
#  'tmpfs                        1,5T   51M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  5,0G  952G   1% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  9,3T  132G  99% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  917G  8,6T  10% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  916G  8,6T  10% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,7T  839G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  6,7T  2,8T  71% /bioinformatica6\n',
#  'tmpfs                        303G  140K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   68K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun oct 15 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  229M  303G   1% /run\n',
#  '/dev/sda3                    265G  123G  129G  49% /\n',
#  'tmpfs                        1,5T   54M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  5,4G  952G   1% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  9,3T  132G  99% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  917G  8,6T  10% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,9T  6,6T  31% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  7,8T  1,8T  82% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  6,7T  2,8T  71% /bioinformatica6\n',
#  'tmpfs                        303G  136K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   56K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun oct 22 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  259M  303G   1% /run\n',
#  '/dev/sda3                    265G  120G  132G  48% /\n',
#  'tmpfs                        1,5T   28M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G   69G  888G   8% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  2,4T  7,1T  26% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  3,2T  6,3T  34% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  7,8T  1,8T  82% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  6,7T  2,8T  71% /bioinformatica6\n',
#  'tmpfs                        303G  144K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   72K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun oct 29 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  283M  303G   1% /run\n',
#  '/dev/sda3                    265G  120G  132G  48% /\n',
#  'tmpfs                        1,5T   28M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G   70G  888G   8% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  2,4T  7,1T  26% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  5,0T  4,5T  53% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  7,8T  1,8T  82% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  6,7T  2,8T  71% /bioinformatica6\n',
#  'tmpfs                        303G  152K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   76K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun nov  5 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  320M  303G   1% /run\n',
#  '/dev/sda3                    265G   60G  192G  24% /\n',
#  'tmpfs                        1,5T   89M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G   70G  888G   8% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  9,5T   27M 100% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,2T  1,4T  87% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  7,8T  1,8T  82% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  6,7T  2,8T  71% /bioinformatica6\n',
#  'tmpfs                        303G  148K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   68K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun nov 12 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  344M  303G   1% /run\n',
#  '/dev/sda3                    265G   63G  189G  25% /\n',
#  'tmpfs                        1,5T  150M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G   70G  888G   8% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  8,6T  922G  91% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  937G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  852G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,0T  486G  95% /bioinformatica6\n',
#  'tmpfs                        303G  156K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   68K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun nov 19 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  360M  303G   1% /run\n',
#  '/dev/sda3                    265G   63G  190G  25% /\n',
#  'tmpfs                        1,5T   83M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G  479G     0 100% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  410G  548G  43% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,6T  2,0T  80% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,8T  697G  93% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  852G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,0T  486G  95% /bioinformatica6\n',
#  'tmpfs                        303G  156K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   68K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun nov 26 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  392M  302G   1% /run\n',
#  '/dev/sda3                    265G   61G  191G  25% /\n',
#  'tmpfs                        1,5T   97M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G  479G     0 100% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  410G  548G  43% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,6T  1,9T  80% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  411G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  935G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  852G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  8,7T  805G  92% /bioinformatica6\n',
#  'tmpfs                        303G  156K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   76K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun dic  3 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  404M  302G   1% /run\n',
#  '/dev/sda3                    265G   64G  189G  26% /\n',
#  'tmpfs                        1,5T  133M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G  479G     0 100% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,6T  1,9T  80% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  935G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  852G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  8,7T  778G  92% /bioinformatica6\n',
#  'tmpfs                        303G  208K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   80K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun dic 10 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  420M  302G   1% /run\n',
#  '/dev/sda3                    265G   72G  180G  29% /\n',
#  'tmpfs                        1,5T  111M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G  479G     0 100% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  7,8T  1,7T  83% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,6T  1,9T  80% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  935G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  852G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  8,8T  687G  93% /bioinformatica6\n',
#  'tmpfs                        303G  192K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   80K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun dic 17 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  458M  302G   1% /run\n',
#  '/dev/sda3                    265G   72G  181G  29% /\n',
#  'tmpfs                        1,5T  123M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk11-vol11  493G   70M  467G   1% /biotemp3\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  8,6T  934G  91% /biodatatmp\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  934G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  851G  92% /biodata4\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  'tmpfs                        303G  192K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   80K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G     0  303G   0% /run/user/1000\n',
#  'lun dic 24 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  116M  303G   1% /run\n',
#  '/dev/sda3                    265G   94G  159G  38% /\n',
#  'tmpfs                        1,5T   52M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  851G  92% /biodata4\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  934G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  8,3T  1,2T  88% /biodatatmp\n',
#  'tmpfs                        303G   40K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   16K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G   20K  303G   1% /run/user/1003\n',
#  '/dev/mapper/biodisk11-vol11   10T   37M  9,5T   1% /biotemp3\n',
#  'lun dic 31 08:15:01 -05 2018\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  292M  303G   1% /run\n',
#  '/dev/sda3                    265G   94G  159G  38% /\n',
#  'tmpfs                        1,5T   52M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  851G  92% /biodata4\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  934G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  8,3T  1,2T  88% /biodatatmp\n',
#  'tmpfs                        303G   36K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   16K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G   24K  303G   1% /run/user/1003\n',
#  '/dev/mapper/biodisk11-vol11   10T   37M  9,5T   1% /biotemp3\n',
#  'lun ene  7 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  476M  302G   1% /run\n',
#  '/dev/sda3                    265G   94G  159G  38% /\n',
#  'tmpfs                        1,5T   52M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  851G  92% /biodata4\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  934G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  '/dev/mapper/biodisk2-vol2     10T  8,3T  1,2T  88% /biodatatmp\n',
#  'tmpfs                        303G   36K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   16K  303G   1% /run/user/1006\n',
#  'tmpfs                        303G   28K  303G   1% /run/user/1003\n',
#  '/dev/mapper/biodisk11-vol11   10T   37M  9,5T   1% /biotemp3\n',
#  'lun ene 14 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G   84M  303G   1% /run\n',
#  '/dev/sda3                    265G  113G  140G  45% /\n',
#  'tmpfs                        1,5T   19M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  8,6T  934G  91% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T   37M  9,5T   1% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  851G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  8,3T  1,2T  88% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   28K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   20K  303G   1% /run/user/1003\n',
#  'lun ene 21 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  278M  303G   1% /run\n',
#  '/dev/sda3                    265G  114G  138G  46% /\n',
#  'tmpfs                        1,5T   84M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,0T  7,6T  21% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  6,7T  2,8T  71% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  9,3T  171G  99% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  410G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   80K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/1006\n',
#  'lun ene 28 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  480M  302G   1% /run\n',
#  '/dev/sda3                    265G  149G  103G  60% /\n',
#  'tmpfs                        1,5T   93M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,0T  7,6T  21% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  846G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  407G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   76K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/1006\n',
#  'lun feb  4 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  672M  302G   1% /run\n',
#  '/dev/sda3                    265G  154G   99G  61% /\n',
#  'tmpfs                        1,5T  183M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  417G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,0T  7,6T  21% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  846G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  407G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   72K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   36K  303G   1% /run/user/1006\n',
#  'lun feb 11 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  872M  302G   1% /run\n',
#  '/dev/sda3                    265G  153G   99G  61% /\n',
#  'tmpfs                        1,5T   95M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  418G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  597G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,1T  7,4T  22% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  844G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  407G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   28K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   80K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/1006\n',
#  'lun feb 18 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  1,1G  302G   1% /run\n',
#  '/dev/sda3                    265G  154G   98G  62% /\n',
#  'tmpfs                        1,5T   96M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  418G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  596G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,1T  7,4T  22% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  845G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  407G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   96K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   24K  303G   1% /run/user/1006\n',
#  'lun feb 25 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  1,3G  302G   1% /run\n',
#  '/dev/sda3                    265G  154G   98G  62% /\n',
#  'tmpfs                        1,5T   84M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  418G  540G  44% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  596G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,1T  7,4T  22% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  845G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  407G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   28K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   88K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   24K  303G   1% /run/user/1006\n',
#  'lun mar  4 08:15:02 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  1,5G  301G   1% /run\n',
#  '/dev/sda3                    265G  155G   97G  62% /\n',
#  'tmpfs                        1,5T   64M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  424G  534G  45% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  596G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  2,1T  7,4T  22% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  845G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  402G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,3T  207G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/108\n',
#  'tmpfs                        303G   92K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   68K  303G   1% /run/user/1006\n',
#  'lun mar 11 08:15:01 -05 2019\n',
#  'Filesystem                   Size  Used Avail Use% Mounted on\n',
#  'udev                         1,5T     0  1,5T   0% /dev\n',
#  'tmpfs                        303G  1,8G  301G   1% /run\n',
#  '/dev/sda3                    265G  168G   84G  67% /\n',
#  'tmpfs                        1,5T   90M  1,5T   1% /dev/shm\n',
#  'tmpfs                        5,0M     0  5,0M   0% /run/lock\n',
#  'tmpfs                        1,5T     0  1,5T   0% /sys/fs/cgroup\n',
#  '/dev/mapper/biodisk4-vol4   1008G  424G  534G  45% /biosamba\n',
#  '/dev/mapper/biodisk1-vol1     10T  8,9T  596G  94% /biodata2\n',
#  '/dev/mapper/biodisk7-vol7     10T  4,0T  5,5T  43% /biodatatmp2\n',
#  '/dev/mapper/biodisk11-vol11   10T  7,4T  2,2T  78% /biotemp3\n',
#  '/dev/mapper/biodisk9-vol9     10T  8,6T  844G  92% /biodata4\n',
#  '/dev/mapper/biodisk6-vol6     10T  9,1T  402G  96% /biodata1\n',
#  '/dev/mapper/biodisk10-vol10   10T  9,2T  264G  98% /bioinformatica6\n',
#  '/dev/mapper/biodisk2-vol2     10T  7,7T  1,8T  82% /biodatatmp\n',
#  '/dev/mapper/biodisk8-vol8     10T  8,7T  786G  92% /biodatatmp3\n',
#  'tmpfs                        303G   32K  303G   1% /run/user/108\n',
#  'tmpfs                        303G  136K  303G   1% /run/user/1003\n',
#  'tmpfs                        303G   68K  303G   1% /run/user/1006\n']

# %%
list_aux_dates
# Out:
# ['lun oct 8 2018 12:52:00',
#  'lun oct 15 2018 08:15:01',
#  'lun oct 22 2018 08:15:01',
#  'lun oct 29 2018 08:15:01',
#  'lun nov 5 2018 08:15:01',
#  'lun nov 12 2018 08:15:01',
#  'lun nov 19 2018 08:15:01',
#  'lun nov 26 2018 08:15:01',
#  'lun dic 3 2018 08:15:01',
#  'lun dic 10 2018 08:15:01',
#  'lun dic 17 2018 08:15:01',
#  'lun dic 24 2018 08:15:01',
#  'lun dic 31 2018 08:15:01',
#  'lun ene 7 2019 08:15:01',
#  'lun ene 14 2019 08:15:01',
#  'lun ene 21 2019 08:15:01',
#  'lun ene 28 2019 08:15:01',
#  'lun feb 4 2019 08:15:01',
#  'lun feb 11 2019 08:15:01',
#  'lun feb 18 2019 08:15:01',
#  'lun feb 25 2019 08:15:01',
#  'lun mar 4 2019 08:15:02',
#  'lun mar 11 2019 08:15:01']

# %%
dict_temp
# Out:
# OrderedDict([(21,
#               [('/biotemp3', 1),
#                ('/biosamba', 1),
#                ('/biodatatmp3', 99),
#                ('/biodatatmp', 10),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 10),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 71)]),
#              (41,
#               [('/biotemp3', 1),
#                ('/biosamba', 1),
#                ('/biodatatmp3', 99),
#                ('/biodatatmp', 10),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 31),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              (61,
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 26),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 34),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              (81,
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 26),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 53),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              (101,
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', '100'),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 87),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              (121,
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 91),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 95)]),
#              (141,
#               [('/biotemp3', 100),
#                ('/biosamba', 43),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 93),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 95)]),
#              (161,
#               [('/biotemp3', 100),
#                ('/biosamba', 43),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 92)]),
#              (181,
#               [('/biotemp3', 100),
#                ('/biosamba', 44),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 92)]),
#              (201,
#               [('/biotemp3', 100),
#                ('/biosamba', 44),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 93)]),
#              (221,
#               [('/biotemp3', 1),
#                ('/biosamba', 44),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 91),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 98)]),
#              (241,
#               [('/bioinformatica6', 98),
#                ('/biodata4', 92),
#                ('/biosamba', 44),
#                ('/biodatatmp2', 91),
#                ('/biodata1', 96),
#                ('/biodata2', 94),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 88),
#                ('/biotemp3', 1)]),
#              (261,
#               [('/bioinformatica6', 98),
#                ('/biodata4', 92),
#                ('/biosamba', 44),
#                ('/biodatatmp2', 91),
#                ('/biodata1', 96),
#                ('/biodata2', 94),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 88),
#                ('/biotemp3', 1)]),
#              (281,
#               [('/bioinformatica6', 98),
#                ('/biodata4', 92),
#                ('/biosamba', 44),
#                ('/biodatatmp2', 91),
#                ('/biodata1', 96),
#                ('/biodata2', 94),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 88),
#                ('/biotemp3', 1)]),
#              (300,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 91),
#                ('/biotemp3', 1),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 88),
#                ('/biodatatmp3', 92)]),
#              (320,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 21),
#                ('/biotemp3', 71),
#                ('/biodata4', 99),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              (340,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 21),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              (360,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 21),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              (380,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              (400,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              (420,
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              (440,
#               [('/biosamba', 45),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)])])

# %%
for date_name, idx_name in zip(list_aux_dates[0:22],dict_temp.keys()):
    print(date_name,idx_name)
    dict_temp[date_name] = dict_temp.pop(idx_name)
# Out:
# ('lun oct 8 2018 12:52:00', 21)
# ('lun oct 15 2018 08:15:01', 41)
# ('lun oct 22 2018 08:15:01', 61)
# ('lun oct 29 2018 08:15:01', 81)
# ('lun nov 5 2018 08:15:01', 101)
# ('lun nov 12 2018 08:15:01', 121)
# ('lun nov 19 2018 08:15:01', 141)
# ('lun nov 26 2018 08:15:01', 161)
# ('lun dic 3 2018 08:15:01', 181)
# ('lun dic 10 2018 08:15:01', 201)
# ('lun dic 17 2018 08:15:01', 221)
# ('lun dic 24 2018 08:15:01', 241)
# ('lun dic 31 2018 08:15:01', 261)
# ('lun ene 7 2019 08:15:01', 281)
# ('lun ene 14 2019 08:15:01', 300)
# ('lun ene 21 2019 08:15:01', 320)
# ('lun ene 28 2019 08:15:01', 340)
# ('lun feb 4 2019 08:15:01', 360)
# ('lun feb 11 2019 08:15:01', 380)
# ('lun feb 18 2019 08:15:01', 400)
# ('lun feb 25 2019 08:15:01', 420)
# ('lun mar 4 2019 08:15:02', 440)

# %%
dict_temp
# Out:
# OrderedDict([('lun oct 8 2018 12:52:00',
#               [('/biotemp3', 1),
#                ('/biosamba', 1),
#                ('/biodatatmp3', 99),
#                ('/biodatatmp', 10),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 10),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 71)]),
#              ('lun oct 15 2018 08:15:01',
#               [('/biotemp3', 1),
#                ('/biosamba', 1),
#                ('/biodatatmp3', 99),
#                ('/biodatatmp', 10),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 31),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              ('lun oct 22 2018 08:15:01',
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 26),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 34),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              ('lun oct 29 2018 08:15:01',
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 26),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 53),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              ('lun nov 5 2018 08:15:01',
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', '100'),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 87),
#                ('/biodata4', 82),
#                ('/bioinformatica6', 71)]),
#              ('lun nov 12 2018 08:15:01',
#               [('/biotemp3', 1),
#                ('/biosamba', 8),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 91),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 95)]),
#              ('lun nov 19 2018 08:15:01',
#               [('/biotemp3', 100),
#                ('/biosamba', 43),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 93),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 95)]),
#              ('lun nov 26 2018 08:15:01',
#               [('/biotemp3', 100),
#                ('/biosamba', 43),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 92)]),
#              ('lun dic 3 2018 08:15:01',
#               [('/biotemp3', 100),
#                ('/biosamba', 44),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 92)]),
#              ('lun dic 10 2018 08:15:01',
#               [('/biotemp3', 100),
#                ('/biosamba', 44),
#                ('/biodatatmp3', 83),
#                ('/biodatatmp', 80),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 93)]),
#              ('lun dic 17 2018 08:15:01',
#               [('/biotemp3', 1),
#                ('/biosamba', 44),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 91),
#                ('/biodata2', 94),
#                ('/biodata1', 96),
#                ('/biodatatmp2', 91),
#                ('/biodata4', 92),
#                ('/bioinformatica6', 98)]),
#              ('lun dic 24 2018 08:15:01',
#               [('/bioinformatica6', 98),
#                ('/biodata4', 92),
#                ('/biosamba', 44),
#                ('/biodatatmp2', 91),
#                ('/biodata1', 96),
#                ('/biodata2', 94),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 88),
#                ('/biotemp3', 1)]),
#              ('lun dic 31 2018 08:15:01',
#               [('/bioinformatica6', 98),
#                ('/biodata4', 92),
#                ('/biosamba', 44),
#                ('/biodatatmp2', 91),
#                ('/biodata1', 96),
#                ('/biodata2', 94),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 88),
#                ('/biotemp3', 1)]),
#              ('lun ene 7 2019 08:15:01',
#               [('/bioinformatica6', 98),
#                ('/biodata4', 92),
#                ('/biosamba', 44),
#                ('/biodatatmp2', 91),
#                ('/biodata1', 96),
#                ('/biodata2', 94),
#                ('/biodatatmp3', 92),
#                ('/biodatatmp', 88),
#                ('/biotemp3', 1)]),
#              ('lun ene 14 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 91),
#                ('/biotemp3', 1),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 88),
#                ('/biodatatmp3', 92)]),
#              ('lun ene 21 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 21),
#                ('/biotemp3', 71),
#                ('/biodata4', 99),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              ('lun ene 28 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 21),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              ('lun feb 4 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 21),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              ('lun feb 11 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              ('lun feb 18 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              ('lun feb 25 2019 08:15:01',
#               [('/biosamba', 44),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)]),
#              ('lun mar 4 2019 08:15:02',
#               [('/biosamba', 45),
#                ('/biodata2', 94),
#                ('/biodatatmp2', 22),
#                ('/biotemp3', 78),
#                ('/biodata4', 92),
#                ('/biodata1', 96),
#                ('/bioinformatica6', 98),
#                ('/biodatatmp', 82),
#                ('/biodatatmp3', 92)])])

# %% [markdown]
# ### Other

# %%
# Using collections to fill the dict
from collections import defaultdict
#tree = lambda: defaultdict(tree)
dict_by_date_of_filesytem = dict()

# creating parsedatetime object
cal = pdt.Calendar()

# Using with to not have to use f.open and f.close
infile = open("output/df_h_output_biomega.txt","r").readlines()
#previous = next(infile)

list_sub_tuples = list()
temp_tuple=("","")
for idx,line in enumerate(infile):
   
    #print(line)
    #print(previous,line)
    if(line.startswith("mar") or line.startswith("lun") ):
        temp_date = getting_temp_date(line)
    else:
        if(line.startswith("Filesystem") != True):
            temp_name_disk,temp_usage = getting_tem_tuple(line) 
            #continue
            temp_tuple = (temp_name_disk,temp_usage)
            if(not all(temp_tuple) != True):
                list_sub_tuples.append(temp_tuple)
    
    if(line.startswith("Filesystem") == True):
        print(temp_date,list_sub_tuples)
    
    #if(list_sub_tuples[len(list_sub_tuples)][0]=="/biotemp3"):
    #    print(idx,temp_date,temp_tuple)
    
    #if(not all(temp_tuple) != True):
        #print(idx,temp_date,temp_tuple)
    #print(temp_date,list_sub_tuples)
    # Filling final dict
    #dict_by_date_of_filesytem[temp_date] = list_sub_tuples
# Out:
# WARNING:root:Luego de split, el numero de available usage no se puede pasar a int
# ('lun oct 8 2018 12:52:00', [])
# ('lun oct 15 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71)])
# ('lun oct 22 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71)])
# ('lun oct 29 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71)])
# ('lun nov 5 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71)])
# ('lun nov 12 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71)])
# ('lun nov 19 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95)])
# ('lun nov 26 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95)])
# ('lun dic 3 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92)])
# ('lun dic 10 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92)])
# ('lun dic 17 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93)])
# ('lun dic 24 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98)])
# ('lun dic 31 2018 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1)])
# ('lun ene 7 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1)])
# ('lun ene 14 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1)])
# ('lun ene 21 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92)])
# ('lun ene 28 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# ('lun feb 4 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# ('lun feb 11 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# ('lun feb 18 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# ('lun feb 25 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# ('lun mar 4 2019 08:15:02', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92)])
# ('lun mar 11 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 45), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3',  ...
# ('lun mar 11 2019 08:15:01', [('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 10), ('/biodata4', 92), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 1), ('/biodatatmp3', 99), ('/biodatatmp', 10), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 31), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 34), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 26), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 53), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', '100'), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 87), ('/biodata4', 82), ('/bioinformatica6', 71), ('/biotemp3', 1), ('/biosamba', 8), ('/biodatatmp3', 83), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 93), ('/biodata4', 92), ('/bioinformatica6', 95), ('/biotemp3', 100), ('/biosamba', 43), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 92), ('/biotemp3', 100), ('/biosamba', 44), ('/biodatatmp3', 83), ('/biodatatmp', 80), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 93), ('/biotemp3', 1), ('/biosamba', 44), ('/biodatatmp3', 92), ('/biodatatmp', 91), ('/biodata2', 94), ('/biodata1', 96), ('/biodatatmp2', 91), ('/biodata4', 92), ('/bioinformatica6', 98), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/bioinformatica6', 98), ('/biodata4', 92), ('/biosamba', 44), ('/biodatatmp2', 91), ('/biodata1', 96), ('/biodata2', 94), ('/biodatatmp3', 92), ('/biodatatmp', 88), ('/biotemp3', 1), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 91), ('/biotemp3', 1), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 88), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 71), ('/biodata4', 99), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 21), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 44), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3', 78), ('/biodata4', 92), ('/biodata1', 96), ('/bioinformatica6', 98), ('/biodatatmp', 82), ('/biodatatmp3', 92), ('/biosamba', 45), ('/biodata2', 94), ('/biodatatmp2', 22), ('/biotemp3',  ...
